# %%
import pandas as pd
import numpy as np
import seaborn as sns
import warnings 
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Train Data

# %%
df=pd.read_csv(r"C:\Users\AYUSHI\Desktop\Flip Robo\Project-Housing_splitted\train.csv")

# %%
df
# Out:
#        Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0     127         120       RL          NaN     4928   Pave   NaN      IR1
# 1     889          20       RL         95.0    15865   Pave   NaN      IR1
# 2     793          60       RL         92.0     9920   Pave   NaN      IR1
# 3     110          20       RL        105.0    11751   Pave   NaN      IR1
# 4     422          20       RL          NaN    16635   Pave   NaN      IR1
# ...   ...         ...      ...          ...      ...    ...   ...      ...
# 1163  289          20       RL          NaN     9819   Pave   NaN      IR1
# 1164  554          20       RL         67.0     8777   Pave   NaN      Reg
# 1165  196         160       RL         24.0     2280   Pave   NaN      Reg
# 1166   31          70  C (all)         50.0     8500   Pave  Pave      Reg
# 1167  617          60       RL          NaN     7861   Pave   NaN      IR1
#
# ...

# %%
df.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
result=df.isnull().sum()
result.to_csv('Null.csv',index = False)

# %% [markdown]
# ### Checking for Null Values

# %%
df.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      214
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
result=df.dtypes
result.to_csv('Data.csv',index = False)

# %% [markdown]
# ### Checking the data types

# %%
df.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
#                   ...
# MoSold             int64
# YrSold             int64
# SaleType          object
# SaleCondition     object
# SalePrice          int64
# Length: 81, dtype: object

# %% [markdown]
# ### Visualization of Data

# %%
Columns=[]
Columns=df.columns
import matplotlib.pyplot as plt  
for i in Columns:
    print(df[i].value_counts())
    ax=sns.countplot(x=i,data=df)
    plt.figure(figsize=(15,5))
# Out:
# 1       1
# 946     1
# 964     1
# 963     1
# 962     1
#        ..
# 480     1
# 479     1
# 478     1
# 477     1
# 1460    1
# Name: Id, Length: 1168, dtype: int64
# 20     428
# 60     244
# 50     113
# 120     69
# 70      53
# 30      52
# 160     47
# 80      43
# 90      41
# 190     26
# 85      19
# 75      14
# 45      10
# 180      6
# 40       3
# Name: MSSubClass, dtype: int64
# RL         928
# RM         163
# FV          52
# RH          16
# C (all)      9
# Name: MSZoning, dtype: int64
# 70.98847     214
# 60.00000     111
# 80.00000      60
# 70.00000      58
# 75.00000      46
#             ...
# 141.00000      1
# 144.00000      1
# 111.00000      1
# 39.00000       1
# 46.00000       1
# Name: LotFrontage, Length: 107, dtype: int64
# 9600     21
# 7200     18
# 6000     16
# 8400     14
# 10800    11
#          ..
# 11103     1
# 19296     1
# 12274     1
# 9060      1
# 8190      1
# Name: LotArea, Length: 892, dtype: int64
# Pave    1164
# Grvl       4
# ...

# %% [markdown]
# ### Handling the null values: To remove the null values,for float data types we use mean of remaining data and for object data types we use mode of remaining data

# %%
df['LotFrontage']=df['LotFrontage'].replace('',np.nan)

# %%
df['LotFrontage']=df['LotFrontage'].fillna(np.mean(df["LotFrontage"]))

# %%
df['Alley']=df['Alley'].replace('',np.nan)

# %%
from statistics import mode
df['Alley']=df['Alley'].fillna(mode(df["Alley"]))

# %%
df['MasVnrType']=df['MasVnrType'].replace('',np.nan)

# %%
df['MasVnrType']=df['MasVnrType'].fillna(mode(df["MasVnrType"]))

# %%
df['MasVnrArea']=df['MasVnrArea'].replace('',np.nan)

# %%
df['MasVnrArea']=df['MasVnrArea'].fillna(np.mean(df["MasVnrArea"]))

# %%
df['BsmtQual']=df['BsmtQual'].replace('',np.nan)

# %%
df['BsmtQual']=df['BsmtQual'].fillna(mode(df["BsmtQual"]))

# %%
df['BsmtCond']=df['BsmtCond'].replace('',np.nan)

# %%
df['BsmtCond']=df['BsmtCond'].fillna(mode(df["BsmtCond"]))

# %%
df['BsmtExposure']=df['BsmtExposure'].replace('',np.nan)

# %%
df['BsmtExposure']=df['BsmtExposure'].fillna(mode(df["BsmtExposure"]))

# %%
df['BsmtFinType1']=df['BsmtFinType1'].replace('',np.nan)

# %%
df['BsmtFinType1']=df['BsmtFinType1'].fillna(mode(df["BsmtFinType1"]))

# %%
df['BsmtFinType2']=df['BsmtFinType2'].replace('',np.nan)

# %%
df['BsmtFinType2']=df['BsmtFinType2'].fillna(mode(df["BsmtFinType2"]))

# %%
df['FireplaceQu']=df['FireplaceQu'].replace('',np.nan)

# %%
df['FireplaceQu']=df['FireplaceQu'].fillna(mode(df["FireplaceQu"]))

# %%
df['GarageType']=df['GarageType'].replace('',np.nan)

# %%
df['GarageType']=df['GarageType'].fillna(mode(df["GarageType"]))

# %%
df['GarageFinish']=df['GarageFinish'].replace('',np.nan)

# %%
df['GarageFinish']=df['GarageFinish'].fillna(mode(df["GarageFinish"]))

# %%
df['GarageYrBlt']=df['GarageYrBlt'].replace('',np.nan)

# %%
df['GarageYrBlt']=df['GarageYrBlt'].fillna(np.mean(df["GarageYrBlt"]))

# %%
df['GarageQual']=df['GarageQual'].replace('',np.nan)

# %%
df['GarageQual']=df['GarageQual'].fillna(mode(df["GarageQual"]))

# %%
df['GarageCond']=df['GarageCond'].replace('',np.nan)

# %%
df['GarageCond']=df['GarageCond'].fillna(mode(df["GarageCond"]))

# %%
df['PoolQC']=df['PoolQC'].replace('',np.nan)

# %%
df['PoolQC']=df['PoolQC'].fillna(mode(df["PoolQC"]))

# %%
df['Fence']=df['Fence'].replace('',np.nan)

# %%
df['Fence']=df['Fence'].fillna(mode(df["Fence"]))

# %%
df['MiscFeature']=df['MiscFeature'].replace('',np.nan)

# %%
df['MiscFeature']=df['MiscFeature'].fillna(mode(df["MiscFeature"]))

# %%
result=df.isnull().sum()
result.to_csv('NoNull.csv',index = False)

# %% [markdown]
# ### As maximum values for the below columns are null, we cannot use the mode as it will be biased data, thus dropping these columns
# Alley	1091
# PoolQC	1161
# Fence	931
# MiscFeature	1124
# FireplaceQu	551
# ### And Utilities have same value for all rows thus dropping it as it will not contribute to the modelling

# %%
df1=df.drop("PoolQC",axis=1)
df2=df1.drop("Fence",axis=1)
df3=df2.drop("MiscFeature",axis=1)
df4=df3.drop("FireplaceQu",axis=1)
df5=df4.drop("Utilities",axis=1)
Sales=df5.drop("Alley",axis=1)

# %%
Sales
# Out:
#        Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape  \
# 0     127         120       RL     70.98847     4928   Pave      IR1
# 1     889          20       RL     95.00000    15865   Pave      IR1
# 2     793          60       RL     92.00000     9920   Pave      IR1
# 3     110          20       RL    105.00000    11751   Pave      IR1
# 4     422          20       RL     70.98847    16635   Pave      IR1
# ...   ...         ...      ...          ...      ...    ...      ...
# 1163  289          20       RL     70.98847     9819   Pave      IR1
# 1164  554          20       RL     67.00000     8777   Pave      Reg
# 1165  196         160       RL     24.00000     2280   Pave      Reg
# 1166   31          70  C (all)     50.00000     8500   Pave      Reg
# 1167  617          60       RL     70.98847     7861   Pave      IR1
#
#      LandContour LotConfig LandSlope  ... EnclosedPorch 3SsnPorch ScreenPorch  \
# ...

# %%
Sales.isnull().sum()
# Out:
# Id               0
# MSSubClass       0
# MSZoning         0
# LotFrontage      0
# LotArea          0
#                 ..
# MoSold           0
# YrSold           0
# SaleType         0
# SaleCondition    0
# SalePrice        0
# Length: 75, dtype: int64

# %% [markdown]
# ### All null values removed, now We need to encode the columns that have object type data

# %%
from sklearn.preprocessing import OrdinalEncoder
enc=OrdinalEncoder()

# %%
for i in Sales.columns:
    if Sales[i].dtypes=="object":
        Sales[i]=enc.fit_transform(Sales[i].values.reshape(-1,1))

# %%
Sales
# Out:
#        Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  LotShape  \
# 0     127         120       3.0     70.98847     4928     1.0       0.0
# 1     889          20       3.0     95.00000    15865     1.0       0.0
# 2     793          60       3.0     92.00000     9920     1.0       0.0
# 3     110          20       3.0    105.00000    11751     1.0       0.0
# 4     422          20       3.0     70.98847    16635     1.0       0.0
# ...   ...         ...       ...          ...      ...     ...       ...
# 1163  289          20       3.0     70.98847     9819     1.0       0.0
# 1164  554          20       3.0     67.00000     8777     1.0       3.0
# 1165  196         160       3.0     24.00000     2280     1.0       3.0
# 1166   31          70       0.0     50.00000     8500     1.0       3.0
# 1167  617          60       3.0     70.98847     7861     1.0       0.0
#
#       LandContour  LotConfig  LandSlope  ...  EnclosedPorch  3SsnPorch  \
# ...

# %% [markdown]
# ### Checking the correlation

# %%
Sales.corr()
# Out:
#                      Id  MSSubClass  MSZoning  LotFrontage   LotArea  \
# Id             1.000000    0.004259  0.009307    -0.005969 -0.029212
# MSSubClass     0.004259    1.000000  0.007478    -0.336681 -0.124151
# MSZoning       0.009307    0.007478  1.000000    -0.069661 -0.023328
# LotFrontage   -0.005969   -0.336681 -0.069661     1.000000  0.299452
# LotArea       -0.029212   -0.124151 -0.023328     0.299452  1.000000
# ...                 ...         ...       ...          ...       ...
# MoSold         0.023479   -0.016015 -0.051646     0.022517  0.015141
# YrSold        -0.008853   -0.038595 -0.004964    -0.003885 -0.035399
# SaleType       0.024384    0.035050  0.079854    -0.035356  0.005421
# SaleCondition -0.014726   -0.028981  0.004501     0.065091  0.034236
# SalePrice     -0.023897   -0.060775 -0.133221     0.323779  0.249499
#
#                  Street  LotShape  LandContour  LotConfig  LandSlope  ...  \
# ...

# %%
Sales.corr()['SalePrice'].sort_values(ascending=False)
# Out:
# SalePrice       1.000000
# OverallQual     0.789185
# GrLivArea       0.707300
# GarageCars      0.628329
# GarageArea      0.619000
#                   ...
# HeatingQC      -0.406604
# GarageFinish   -0.537121
# KitchenQual    -0.592468
# ExterQual      -0.624820
# BsmtQual       -0.626850
# Name: SalePrice, Length: 75, dtype: float64

# %% [markdown]
# ### We see that the factors affecting the House Sale Price are OverallQual,GrLivArea,GarageCars,GarageArea But the most important positively affecting factor is OverallQual as it Rates the overall material and finish of the house which is important factor when a person is buying a house.  Also the negative factors affecting the SalePrice  is the BsmtQual, ExterQual, KitchenQual and GarageFinish

# %%
import matplotlib.pyplot as plt  
plt.figure(figsize=(15,7))
sns.heatmap(Sales.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
Sales.describe()
# Out:
#                 Id   MSSubClass     MSZoning  LotFrontage        LotArea  \
# count  1168.000000  1168.000000  1168.000000  1168.000000    1168.000000
# mean    724.136130    56.767979     3.013699    70.988470   10484.749144
# std     416.159877    41.940650     0.633120    22.437056    8957.442311
# min       1.000000    20.000000     0.000000    21.000000    1300.000000
# 25%     360.500000    20.000000     3.000000    60.000000    7621.500000
# 50%     714.500000    50.000000     3.000000    70.988470    9522.500000
# 75%    1079.500000    70.000000     3.000000    79.250000   11515.500000
# max    1460.000000   190.000000     4.000000   313.000000  164660.000000
#
#             Street     LotShape  LandContour    LotConfig    LandSlope  ...  \
# count  1168.000000  1168.000000  1168.000000  1168.000000  1168.000000  ...
# mean      0.996575     1.938356     2.773973     3.004281     0.064212  ...
# std       0.058445     1.412262     0.710027     1.642667     0.284088  ...
# ...

# %% [markdown]
# ### Seperating the independent and dependent variable

# %%
x=Sales.drop("SalePrice",axis=1)
y=Sales["SalePrice"]

# %%
x.skew().sort_values(ascending=False)
# Out:
# MiscVal       23.065943
# PoolArea      13.243711
# Condition2    11.514458
# LotArea       10.659285
# Heating       10.103609
#                 ...
# SaleType      -3.660513
# Functional    -3.999663
# GarageQual    -4.582386
# GarageCond    -5.422472
# Street       -17.021969
# Length: 74, dtype: float64

# %% [markdown]
# ### We see that the data is skewed and to bring the skewness in the range of (-0.5,0.5) using power transform

# %%
from sklearn.preprocessing import power_transform
x_new=power_transform(x)

# %%
type(x_new)
# Out:
# numpy.ndarray

# %%
x=pd.DataFrame(x_new,columns=x.columns)

# %%
x
# Out:
#             Id  MSSubClass  MSZoning  LotFrontage   LotArea    Street  \
# 0    -1.544968    1.370435 -0.162456     0.093658 -1.213954  0.058621
# 1     0.461941   -1.167999 -0.162456     1.117135  1.100521  0.058621
# 2     0.254221    0.490047 -0.162456     0.998803  0.158048  0.058621
# 3    -1.610857   -1.167999 -0.162456     1.495566  0.496002  0.058621
# 4    -0.635571   -1.167999 -0.162456     0.093658  1.196626  0.058621
# ...        ...         ...       ...          ...       ...       ...
# 1163 -1.008279   -1.167999 -0.162456     0.093658  0.137703  0.058621
# 1164 -0.299331   -1.167999 -0.162456    -0.096350 -0.084786  0.058621
# 1165 -1.300337    1.700798 -0.162456    -2.852857 -2.681835  0.058621
# 1166 -1.975680    0.696557 -2.926464    -0.996296 -0.148203  0.058621
# 1167 -0.147481    0.490047 -0.162456     0.093658 -0.302416  0.058621
#
#       LotShape  LandContour  LotConfig  LandSlope  ...  OpenPorchSF  \
# ...

# %%
x.skew().sort_values(ascending=False)
# Out:
# PoolArea        12.817372
# 3SsnPorch        7.087955
# LowQualFinSF     6.922843
# MiscVal          4.991071
# LandSlope        3.954345
#                   ...
# GarageQual      -4.327379
# Heating         -4.541694
# GarageCond      -4.925781
# RoofMatl        -6.314987
# Street         -17.021969
# Length: 74, dtype: float64

# %%
sk=x.skew()

# %%
sk[np.abs(sk)>0.25].all()
# Out:
# True

# %% [markdown]
# ### Now we need to check whether outliers are present in the data or not. For that we need to check if the z value of all the factors are exceeding the range (-3,3)

# %%
x.iloc[:,0:11].boxplot(figsize=[20,8])
plt.subplots_adjust(bottom=0.25)
plt.show()

# %% [markdown]
# ### We see that there are many outliers and we need to remove them

# %%
from scipy.stats import zscore
(np.abs(zscore(x))<3).all()
# Out:
# False

# %%
new_df=pd.concat([x,y],axis=1)
new_df
# Out:
#             Id  MSSubClass  MSZoning  LotFrontage   LotArea    Street  \
# 0    -1.544968    1.370435 -0.162456     0.093658 -1.213954  0.058621
# 1     0.461941   -1.167999 -0.162456     1.117135  1.100521  0.058621
# 2     0.254221    0.490047 -0.162456     0.998803  0.158048  0.058621
# 3    -1.610857   -1.167999 -0.162456     1.495566  0.496002  0.058621
# 4    -0.635571   -1.167999 -0.162456     0.093658  1.196626  0.058621
# ...        ...         ...       ...          ...       ...       ...
# 1163 -1.008279   -1.167999 -0.162456     0.093658  0.137703  0.058621
# 1164 -0.299331   -1.167999 -0.162456    -0.096350 -0.084786  0.058621
# 1165 -1.300337    1.700798 -0.162456    -2.852857 -2.681835  0.058621
# 1166 -1.975680    0.696557 -2.926464    -0.996296 -0.148203  0.058621
# 1167 -0.147481    0.490047 -0.162456     0.093658 -0.302416  0.058621
#
#       LotShape  LandContour  LotConfig  LandSlope  ...  EnclosedPorch  \
# ...

# %%
from scipy.stats import zscore
z=np.abs(zscore(new_df))
new_df=new_df[(z<3).all(axis=1)]

# %%
x=new_df.drop("SalePrice",axis=1)
y=new_df["SalePrice"]

# %%
x.iloc[:,0:11].boxplot(figsize=[20,8])
plt.subplots_adjust(bottom=0.25)
plt.show()

# %% [markdown]
# ### Outliers removed

# %%
x
# Out:
#             Id  MSSubClass  MSZoning  LotFrontage   LotArea    Street  \
# 0    -1.544968    1.370435 -0.162456     0.093658 -1.213954  0.058621
# 2     0.254221    0.490047 -0.162456     0.998803  0.158048  0.058621
# 3    -1.610857   -1.167999 -0.162456     1.495566  0.496002  0.058621
# 5     1.087698    0.490047 -0.162456    -0.552490  0.855555  0.058621
# 9    -0.245746    0.237618 -0.162456     0.499839 -0.152859  0.058621
# ...        ...         ...       ...          ...       ...       ...
# 1158 -0.016349   -1.167999 -0.162456     0.093658  0.408854  0.058621
# 1161  1.287673    0.490047 -0.162456     0.093658  0.320308  0.058621
# 1163 -1.008279   -1.167999 -0.162456     0.093658  0.137703  0.058621
# 1165 -1.300337    1.700798 -0.162456    -2.852857 -2.681835  0.058621
# 1167 -0.147481    0.490047 -0.162456     0.093658 -0.302416  0.058621
#
#       LotShape  LandContour  LotConfig  LandSlope  ...  OpenPorchSF  \
# ...

# %%
y
# Out:
# 0       128000
# 2       269790
# 3       190000
# 5       219210
# 9       118500
#          ...
# 1158    165000
# 1161    225000
# 1163    122000
# 1165    148500
# 1167    183200
# Name: SalePrice, Length: 564, dtype: int64

# %% [markdown]
# ## Model Building

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
from sklearn.preprocessing import MinMaxScaler
mms=MinMaxScaler()
from sklearn.metrics import r2_score

# %%
for i in range (0,1000) :
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=i)
    lr.fit(x_train,y_train)
    pred_test=lr.predict(x_test)
    pred_train=lr.predict(x_train)
    print(f"at random state {i},the training accuracy is :{r2_score(y_train,pred_train)}")
    print(f"at random state {i},the testing accuracy is :{r2_score(y_test,pred_test)}") 
    print("\n")
# Out:
# at random state 0,the training accuracy is :0.9094187767506839
# at random state 0,the testing accuracy is :0.8045450943948743
#
#
# at random state 1,the training accuracy is :0.8948990393513252
# at random state 1,the testing accuracy is :0.8870398318493604
#
#
# at random state 2,the training accuracy is :0.9046187555147076
# at random state 2,the testing accuracy is :0.827931242851051
#
#
# at random state 3,the training accuracy is :0.8961211411499344
# at random state 3,the testing accuracy is :0.8865158507851285
#
#
# at random state 4,the training accuracy is :0.9032094096186617
# at random state 4,the testing accuracy is :0.8540047903136492
#
#
# at random state 5,the training accuracy is :0.8939792933828613
# at random state 5,the testing accuracy is :0.901149231570046
#
#
# at random state 6,the training accuracy is :0.8943813227852527
# at random state 6,the testing accuracy is :0.8884680148883787
#
#
# at random state 7,the training accuracy is :0.9027398009627718
# ...

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=418)

# %%
x_train.shape
# Out:
# (451, 74)

# %%
y_train.shape
# Out:
# (451,)

# %%
x_test.shape
# Out:
# (113, 74)

# %%
y_test.shape
# Out:
# (113,)

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
pred_test=lr.predict(x_test)

# %%
print(r2_score(y_test,pred_test))
# Out:
# 0.8948933974111771

# %% [markdown]
# ## CROSS VALIDATION

# %%
Train_accuracy=r2_score(y_train,pred_train)
Test_accuracy=r2_score(y_test,pred_test)
from sklearn.model_selection import cross_val_score
for j in range(2,10):
    cv_score=cross_val_score(lr,x,y,cv=j)
    cv_mean=cv_score.mean()
    print(f'At cross fold {j} the cv score is {cv_mean} and accuracy score for training is {Train_accuracy}and accuracy score for testing is {Test_accuracy}')
    print('\n')
# Out:
# At cross fold 2 the cv score is 0.8492812637057208 and accuracy score for training is -0.9630898330175612and accuracy score for testing is 0.8948933974111771
#
#
# At cross fold 3 the cv score is 0.8582066582145197 and accuracy score for training is -0.9630898330175612and accuracy score for testing is 0.8948933974111771
#
#
# At cross fold 4 the cv score is 0.8597380128395549 and accuracy score for training is -0.9630898330175612and accuracy score for testing is 0.8948933974111771
#
#
# At cross fold 5 the cv score is 0.8686996163383688 and accuracy score for training is -0.9630898330175612and accuracy score for testing is 0.8948933974111771
#
#
# At cross fold 6 the cv score is 0.8580790685520667 and accuracy score for training is -0.9630898330175612and accuracy score for testing is 0.8948933974111771
#
#
# At cross fold 7 the cv score is 0.8676688702800658 and accuracy score for training is -0.9630898330175612and accuracy score for testing is 0.8948933974111771
#
#
# ...

# %% [markdown]
# ## Plot the Data

# %%
import matplotlib.pyplot as plt 

plt.figure(figsize=(8,6))
plt.scatter(x=y_test,y=pred_test,color='r')
plt.plot(y_test,y_test,color='b')
plt.title("Linear Regression")
plt.show()

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
import warnings 
warnings.filterwarnings('ignore')

# %%
from sklearn.linear_model import Lasso
parameters={'alpha':[.0001,.001,.01,.1,1,10],'random_state':list(range(0,10))}
ls=Lasso()
clf=GridSearchCV(ls,parameters)
clf.fit(x_train,y_train)
print(clf.best_params_)
# Out:
# {'alpha': 10, 'random_state': 0}

# %%
ls=Lasso(alpha=10,random_state=0)
ls.fit(x_train,y_train)
ls.score(x_train,y_train)
pred_ls=ls.predict(x_test)
lss=r2_score(y_test,pred_ls)
lss
# Out:
# 0.8964598211473586

# %%
cv_score=cross_val_score(ls,x,y,cv=3)
cv_mean=cv_score.mean()
cv_mean
# Out:
# 0.8593456878449621

# %% [markdown]
# ## Ensemble technique:

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor

# %%
parameters = {'criterion':['mse','mae'],'max_features':["auto","sqrt","log2"]}
rf=RandomForestRegressor()
clf=GridSearchCV(rf,parameters)
clf.fit(x_train,y_train)
print(clf.best_params_)
# Out:
# {'criterion': 'mse', 'max_features': 'sqrt'}

# %%
rf=RandomForestRegressor(criterion='mse',max_features='sqrt')
rf.fit(x_train,y_train)
rf.score(x_train,y_train)
pred_decision=rf.predict(x_test)


rfs=r2_score(y_test,pred_decision)
print('R2 score:',rfs*100)

rfscore=cross_val_score(rf,x,y,cv=5)
rfc=rfscore.mean()
print('Cross Val Score:',rfc*100)
# Out:
# R2 score: 89.05735508460583
# Cross Val Score: 87.34008584745702

# %% [markdown]
# ## we are getting our model accuracy around 58.95% and cross validation around 57.2 % which shows our model is performing good

# %%
import pickle

# %%
filename='Housing.pkl'
pickle.dump(rf, open(filename,'wb'))

# %% [markdown]
# # Conclusion:

# %%
loaded_model= pickle.load(open('Housing.pkl','rb'))
result=loaded_model.score(x_test,y_test)
print(result)
# Out:
# 0.8905735508460584

# %%
conclusion=pd.DataFrame([loaded_model.predict(x_test)[:],pred_decision[:]],index=["predicted","original"])
conclusion
# Out:
#                  0         1         2         3         4          5    \
# predicted  217241.35  155702.0  190194.0  171253.6  148179.0  173829.08
# original   217241.35  155702.0  190194.0  171253.6  148179.0  173829.08
#
#                  6          7          8          9    ...        103  \
# predicted  193145.34  340979.49  248318.61  139434.58  ...  268445.95
# original   193145.34  340979.49  248318.61  139434.58  ...  268445.95
#
#                  104       105        106        107       108        109  \
# predicted  125618.82  154504.0  194662.19  189990.94  139192.0  240314.05
# original   125618.82  154504.0  194662.19  189990.94  139192.0  240314.05
#
#                  110        111        112
# predicted  221688.68  273971.13  264718.54
# original   221688.68  273971.13  264718.54
#
# [2 rows x 113 columns]

# %% [markdown]
# ## Testing the model with the provided test data

# %%
Sales1=pd.read_csv(r"C:\Users\AYUSHI\Desktop\Flip Robo\Project-Housing_splitted\test.csv")

# %%
Sales1
# Out:
#        Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0     337          20       RL         86.0    14157   Pave   NaN      IR1
# 1    1018         120       RL          NaN     5814   Pave   NaN      IR1
# 2     929          20       RL          NaN    11838   Pave   NaN      Reg
# 3    1148          70       RL         75.0    12000   Pave   NaN      Reg
# 4    1227          60       RL         86.0    14598   Pave   NaN      IR1
# ..    ...         ...      ...          ...      ...    ...   ...      ...
# 287    83          20       RL         78.0    10206   Pave   NaN      Reg
# 288  1048          20       RL         57.0     9245   Pave   NaN      IR2
# 289    17          20       RL          NaN    11241   Pave   NaN      IR1
# 290   523          50       RM         50.0     5000   Pave   NaN      Reg
# 291  1379         160       RM         21.0     1953   Pave   NaN      Reg
#
# ...

# %% [markdown]
# ### Now we need to remove the null values for test data too and then predict the Sale Price for the same

# %%
result=Sales1.isnull().sum()
result.to_csv('New.csv',index = False)

# %%
Sales2=Sales1.drop("PoolQC",axis=1)
Sales3=Sales2.drop("Fence",axis=1)
Sales4=Sales3.drop("MiscFeature",axis=1)
Sales5=Sales4.drop("FireplaceQu",axis=1)
Sales6=Sales5.drop("Utilities",axis=1)
Sales7=Sales6.drop("Alley",axis=1)

# %%
Sales7['LotFrontage']=Sales7['LotFrontage'].replace('',np.nan)

# %%
Sales7['LotFrontage']=Sales7['LotFrontage'].fillna(np.mean(Sales7["LotFrontage"]))

# %%
from statistics import mode

# %%
Sales7['MasVnrType']=Sales7['MasVnrType'].replace('',np.nan)

# %%
Sales7['MasVnrType']=Sales7['MasVnrType'].fillna(mode(Sales7["MasVnrType"]))

# %%
Sales7['MasVnrArea']=Sales7['MasVnrArea'].replace('',np.nan)

# %%
Sales7['MasVnrArea']=Sales7['MasVnrArea'].fillna(np.mean(Sales7["MasVnrArea"]))

# %%
Sales7['BsmtQual']=Sales7['BsmtQual'].replace('',np.nan)

# %%
Sales7['BsmtQual']=Sales7['BsmtQual'].fillna(mode(Sales7["BsmtQual"]))

# %%
Sales7['BsmtCond']=Sales7['BsmtCond'].replace('',np.nan)

# %%
Sales7['BsmtCond']=Sales7['BsmtCond'].fillna(mode(Sales7["BsmtCond"]))

# %%
Sales7['BsmtExposure']=Sales7['BsmtExposure'].replace('',np.nan)

# %%
Sales7['BsmtExposure']=Sales7['BsmtExposure'].fillna(mode(Sales7["BsmtExposure"]))

# %%
Sales7['BsmtFinType1']=Sales7['BsmtFinType1'].replace('',np.nan)

# %%
Sales7['BsmtFinType1']=Sales7['BsmtFinType1'].fillna(mode(Sales7["BsmtFinType1"]))

# %%
Sales7['BsmtFinType2']=Sales7['BsmtFinType2'].replace('',np.nan)

# %%
Sales7['BsmtFinType2']=Sales7['BsmtFinType2'].fillna(mode(Sales7["BsmtFinType2"]))

# %%
Sales7['Electrical']=Sales7['Electrical'].replace('',np.nan)

# %%
Sales7['Electrical']=Sales7['Electrical'].fillna(mode(Sales7["Electrical"]))

# %%
Sales7['GarageType']=Sales7['GarageType'].replace('',np.nan)

# %%
Sales7['GarageType']=Sales7['GarageType'].fillna(mode(Sales7["GarageType"]))

# %%
Sales7['GarageFinish']=Sales7['GarageFinish'].replace('',np.nan)

# %%
Sales7['GarageFinish']=Sales7['GarageFinish'].fillna(mode(Sales7["GarageFinish"]))

# %%
Sales7['GarageYrBlt']=Sales7['GarageYrBlt'].replace('',np.nan)

# %%
Sales7['GarageYrBlt']=Sales7['GarageYrBlt'].fillna(np.mean(Sales7["GarageYrBlt"]))

# %%
Sales7['GarageQual']=Sales7['GarageQual'].replace('',np.nan)

# %%
Sales7['GarageQual']=Sales7['GarageQual'].fillna(mode(Sales7["GarageQual"]))

# %%
Sales7['GarageCond']=Sales7['GarageCond'].replace('',np.nan)

# %%
Sales7['GarageCond']=Sales7['GarageCond'].fillna(mode(Sales7["GarageCond"]))

# %%
result=Sales7.isnull().sum()
result.to_csv('New.csv',index = False)

# %%
for i in Sales7.columns:
    if Sales7[i].dtypes=="object":
        Sales7[i]=enc.fit_transform(Sales7[i].values.reshape(-1,1))

# %%
Sales7
# Out:
#        Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  LotShape  \
# 0     337          20       2.0    86.000000    14157     1.0       0.0
# 1    1018         120       2.0    66.425101     5814     1.0       0.0
# 2     929          20       2.0    66.425101    11838     1.0       3.0
# 3    1148          70       2.0    75.000000    12000     1.0       3.0
# 4    1227          60       2.0    86.000000    14598     1.0       0.0
# ..    ...         ...       ...          ...      ...     ...       ...
# 287    83          20       2.0    78.000000    10206     1.0       3.0
# 288  1048          20       2.0    57.000000     9245     1.0       1.0
# 289    17          20       2.0    66.425101    11241     1.0       0.0
# 290   523          50       3.0    50.000000     5000     1.0       3.0
# 291  1379         160       3.0    21.000000     1953     1.0       3.0
#
#      LandContour  LotConfig  LandSlope  ...  OpenPorchSF  EnclosedPorch  \
# ...

# %%
model_test=pd.DataFrame(loaded_model.predict(Sales7))
model_test
# Out:
#              0
# 0    318609.88
# 1    297387.81
# 2    307159.61
# 3    283559.72
# 4    305990.85
# ..         ...
# 287  312536.60
# 288  296643.21
# 289  306889.83
# 290  303535.46
# 291  293063.00
#
# [292 rows x 1 columns]

# %%
result = pd.DataFrame()
target_var=loaded_model.predict(Sales7)

result["Sale Price"] = target_var
result = result.sort_index()
result.to_csv('Housing_Price_Prediction.csv',index = False)
